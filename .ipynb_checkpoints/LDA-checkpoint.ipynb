# %%
from IPython.core.display import HTML, display
HTML("<style>.container { width:100% !important; }</style>")
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = matplotlib.rcParams['savefig.dpi']

# %%
import pandas as pd
import numpy as np
# import emoji lists from data.sentiment_dict
from Data.sentiment_dict import positive, negative
from sklearn.feature_extraction import DictVectorizer
pd.options.display.max_colwidth=250

# %%
# separate tweet into parts with emojis of interest and the rest
def separate_emoji(tweet, emojis):
    emojis = set(tweet).intersection(emojis)
    text = ''
    for i in tweet:
        if i not in emojis:
            text += i
    return text, dict.fromkeys(emojis,1)

# %%
# specify the location of the tweets
negtweet_file ='./Data/negtweets.txt'
postweet_file ='./Data/postweets.txt'

# %%
# initial lists, one for tweets, one for emoji of interest
tweet_df = [] # so far, it is just lists
emoji_df = []
# load all the tweets from positive file
with open(postweet_file,'r') as f:
    for line in f:
        tweet = line.decode('utf-8')
        emojis = positive+negative
        text_i, emojis_i =separate_emoji(tweet, emojis)
        emoji_df.append(emojis_i) 
        tweet_df.append(text_i)
# load all the tweets from negative file
with open(negtweet_file,'r') as f:
    for line in f:
        tweet = line.decode('utf-8')
        emojis = positive+negative
        text_i, emojis_i =separate_emoji(tweet, emojis)
        emoji_df.append(emojis_i) 
        tweet_df.append(text_i)

# convert data into dataframe
tweet_df = pd.DataFrame(tweet_df, columns=['tweet'])
DV=DictVectorizer()
emoji_df=DV.fit_transform(emoji_df) # this is actually a vector, or matrix, not a df
emoji_list = {}
for i in DV.feature_names_:
    emoji_list[i.encode('raw_unicode_escape')] = i
emoji_list=pd.DataFrame(emoji_list, index=[0])
emoji_list = emoji_list[[i.encode('raw_unicode_escape') for i in DV.feature_names_]]
emoji_df=pd.DataFrame(emoji_df.toarray(), columns=[i.encode('raw_unicode_escape') for i in DV.feature_names_])

# %%
emoji_list
# Out:
#   \u2639 \u263a \U0001f600 \U0001f601 \U0001f602 \U0001f603 \U0001f604  \
# 0      ☹      ☺          😀          😁          😂          😃          😄
#
#   \U0001f606 \U0001f607 \U0001f60a    ...     \U0001f626 \U0001f627  \
# 0          😆          😇          😊    ...              😦          😧
#
#   \U0001f628 \U0001f629 \U0001f62d \U0001f630 \U0001f631 \U0001f638  \
# 0          😨          😩          😭          😰          😱          😸
#
#   \U0001f641 \U0001f642
# 0          🙁          🙂
#
# [1 rows x 34 columns]

# %%
display(tweet_df)
# Out:
#                                                                                                                                         tweet
# 0                                                                                        bro that's so depressing.. Let's go to his house 🙄\n
# 1                                                                          thank you thank you for telling me about them omg i love them ❤x\n
# 2                    Excellent day at work, laughed all day. Blessed to do my job. #crewlife #averybritishairline #post2276gettingthere 👏🏻 \n
# 3                                                                                                                 Things are getting there \n
# 4                                                                  I'm so proud of you! Welcome to the team!! #BellLetsTalk #SickNotWeak   \n
# 5                                                                                                     please follow me  #BellLetsTalk   X18\n
# 6                                                                                                                             thanks girl 💕\n
# 7                                                                                                                      2 weeks from today  \n
# 8                                                                                                          's snapchats cheer me up so much\n
# 9                                                                                                            I'm not sure if I'm going yet \n
# 10                                                                                                                            BRUUUUHHH 💀💀 \n
# 11                                                                                               #SoundsLiveFeelsLive is getting closer    \n
# 12                                                                                                 Fuck me new day are actually incredible \n
# 13                   If Misha and Kanye become friends West can finally marry North and then he'll be West West who wears West's Vests :)))\n
# 14                                                                                                                  lmao add me to that gc \n
# 15                                                                                                       Amber did not have to go that far \n
# 16                                                                                           Why everyone just wilding on Twitter today 💀💀💀\n
# 17                                                                                                     #BellLetsTalk I :) Love :) You :)  ❤\n
# 18                                           RT : Awww  are u mad I'm not around to play in ur asshole anymore? #FingersInTheBootyAssBitch☝\n
# 19                                                                                                                                   bruh  \n
# 20                I'm dying to get a follow from my personal favorite network I'm always reading and sharing your great work  #BostonSports\n
# 21                                                                                                                 Lol, y'all so childish. \n
# 22                                                 I wonder how Rachel's and Ross's daughter is like.  and if Joey finally got married. 😪  \n
# 23                                                                                                                               I'm weak  \n
# 24                                                                                                                                Knew it  \n
# 25                                                                                                                       awweeeee  via~nyee\n
# 26                                                         When she's asks you to sadies with a quote from your favorite show&gt;&gt;❤️    \n
# 27                                                                                            lol okay just like how you dick ride him now \n
# 28                                                                                                               94/100 on my health exam  \n
# 29                                                          Donald Trump better live tweet the GOP debate since he's not going to be there \n
# ...                                                                                                                                       ...
# 49970                                                                                                            I wish I had a bestfriend \n
# 49971          so would I, but don't hold your breath,I would expect the VC to be vocal about issues like this,but silence is all we get :(\n
# 49972                                                                                            you're not coming to a city i can go to :(\n
# 49973                                                                   Drake need to drop views while I still have my 3 month Apple trial \n
# 49974                                                                                                Why is this day going by so damn slow \n
# 49975                                                                                                         Need me a personal , wya ??? \n
# 49976                                                                                                                  Bruh Sunday school  \n
# 49977                                                                                                          I really wanna be home rn :(\n
# 49978                                                                                      Can't believe I just fuckin cracked my tooth!!! \n
# 49979                                                                         When your mom makes u feel worthless n unappreciated asf...🆗😞\n
# 49980                                         The microwave sound, scared little #Sooty  a lot. He is currently, household-noise sensitive.\n
# 49981                                                                         Hi 🙊.\r 💖.\r 💝.\r 💘.\r 💗.\rI'm so sorry for spam .\r .\r5999.\n
# 49982                                                                                                     it was so good I miss it already \n
# 49983                                                                                                                      I am starving :(\n
# 49984      I can't keep living off Richard anymore, I need to find my ambition again in order to  be my own person and have my own income. \n
# 49985                                                          I wanted these wings and a gyro special but that just would of been greedy ✋\n
# 49986                                                                                                        kS05 NDX  #Audi #AudiUK #cars \n
# 49987                                                                                         Should not have spent all day walking around \n
# 49988                                                                     I'm on a roll like cottonelle, I was made for all of this shit 🏈 \n
# 49989                                                                                                                         I'm so tired \n
# 49990                                                                                                                  Aweee grandpa Hill  \n
# 49991                 Every year Dunkin comes out with a new flavor and I fall in love with it and then they discontinue it the next year 💔\n
# 49992                                                                                                                             Yes man  \n
# 49993                                                              you got me a Christmas present as well! I haven't gotten you anything :(\n
# 49994                                                                            ME ON THE OUTSIDE &gt;:( ME ON THE INSIDE: &gt;&gt;&gt;:( \n
# 49995   I bet you $100 you will not read this and follow me. I bet it. I am convinced getting your follow is the definition of impossible! \n
# 49996                                                                                                        Hungry but too lazy to get up \n
# 49997                                                                                                             I love Drake so much man \n
# 49998                                                                                                                           Can't eat..\n
# 49999                                                                                                                        i can't wait  \n
#
# [50000 rows x 1 columns]

# %%
# combine tweet_df with emoji_df
tweet_with_emoji_df = tweet_df.copy()
tweet_with_emoji_df[emoji_df.columns] = emoji_df.copy()

# %%
from sklearn.cross_validation import train_test_split
(train_data, test_data) = train_test_split(tweet_with_emoji_df,random_state=0)

# %%
# data_samples = train_data.tweet.values
# data_samples=np.hstack((train_data.tweet.values, test_data.tweet.values))
data_samples = tweet_with_emoji_df.tweet.values

# %%
# tweet_with_emoji_df.head()
# test_data.shape

# %%
from __future__ import print_function
from time import time

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups

# %%
# n_samples = 2000
n_features = 1000
n_topics = 10
n_top_words = 20

def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

# %%
# Use tf-idf features for NMF.
print("Extracting tf-idf features for NMF...")
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, #max_features=n_features,
                                   stop_words='english')
t0 = time()
tfidf = tfidf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
# Out:
# Extracting tf-idf features for NMF...
# done in 0.778s.

# %%
# Use tf (raw term count) features for LDA.
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=n_features,
                                stop_words='english')
t0 = time()
tf = tf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))

# Fit the NMF model
print("Fitting the NMF model with tf-idf features,"
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_topics, random_state=1, alpha=.1, l1_ratio=.5).fit(tfidf)

print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model:")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)

print("Fitting LDA models with tf features, n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
lda = LatentDirichletAllocation(n_topics=n_topics, max_iter=5,
                                learning_method='online', learning_offset=50.,
                                random_state=0)
t0 = time()
lda.fit(tf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Extracting tf features for LDA...
# done in 0.773s.
# Fitting the NMF model with tf-idf features,n_samples=2000 and n_features=1000...
# done in 9.181s.
#
# Topics in NMF model:
# Topic #0:
# love laurenfollowspree omg amp ya life song bellletstalk girl hi amazing beautiful people make hate best fucking man lol dream
# Topic #1:
# want don bad puppy hair home food pizza rn work talk bed people meet sushi leave life grow eat ice
# Topic #2:
# thank god babe boo omg aw girl youuu awh sweet haha awe rt youu ok awesome following lord amp beautiful
# Topic #3:
# miss man boyfriend guys days friend home babe gonna come brother amp going hair soon best bae old having gone
# Topic #4:
# like feel don look video new watch facetimemenash looks amp subscribe people going forget think better bitch feels girl im
# Topic #5:
# good morning night look luck feel hope thing looks feeling don damn looking sounds girl today feels sound time way
# Topic #6:
# happy birthday hope great make makes bday best enjoy amazing year bless girl wish friend pretty beautiful babe god im
# Topic #7:
# need new stop help hair right phone nails life friends massage come nap house asap food hug rn amp talk
# Topic #8:
# baby girl beautiful poor boy freddie missing louis aw lil look ready father fever congrats home man world ya daddy
# Topic #9:
# day today great hope work bad valentine long tomorrow ve going sad school new amp nice ll pay bed make
# Topic #10:
# cute omg freddie look ass louis video think aww soo picture sooo af yes crying lol congrats stop babe awww
# Topic #11:
# got time lol amp work ve damn home finally ain today school going phone think girl night im hours lmao
# Topic #12:
# oh god gosh sorry yeah okay dear man lol lord hell ffs yes fuck bad wow goodness uh look bless
# Topic #13:
# really right wish sad hate wanna sorry bad don today man going tonight work feeling okay people pretty wait hope
# Topic #14:
# thanks boo girl following rt lol man lot haha sharing babe great ily connect appreciate check awesome ya hope awww
# Topic #15:
# follow laurenfollowspree facetimemenash video watch new think hi bellletstalk hey make lauren nash time dream pls subscribe plz let te
# Topic #16:
# just wanna did say man amp home saw people life let im twitter think ll today wait gotta seen thought
# Topic #17:
# shit hate fuck ain funny talk real man holy say people amp crazy mad gotta ass right did fucking im
# Topic #18:
# sleep night wanna hours tonight tired going wake amp hope hate tomorrow gonna early work trying home went sleepy im
# Topic #19:
# know don think let right wanna lol people did didn ll say make mean hi understand work time anymore talk
#
# Fitting LDA models with tf features, n_samples=2000 and n_features=1000...
# done in 25.397s.
#
# Topics in LDA model:
# Topic #0:
# like gonna guys hair 2016 30 01 spotted freddie black niggas high ask buy till chill 29 voice fr valentine
# Topic #1:
# man fuck tomorrow tonight said god beautiful won music bc 10 babe head dude hit end pic perfect bitches listen
# Topic #2:
# know think im people oh come wish don bitch friends dont mad girls dad cool amber room plz break goodnight
# Topic #3:
# follow hate life love tho real talk hi laurenfollowspree heart bellletstalk literally smile pls lil favorite playing bout hurts snapchat
# Topic #4:
# want time gotta cause rn bed does seen missing read boys asf thx tf goes 6s set lit single bi0
# Topic #5:
# feel cute year lmao live face world old boy talking finally house years lost forever job bring probably ago periscope
# Topic #6:
# day getting better makes having lt ok stay doesn hell hours left leave wasn told dog maybe fine hour smh
# Topic #7:
# phone tell big sick ready wrong mind hungry picture mood asleep ily started lmfao stuff comes em fall anti season
# Topic #8:
# amp right did funny mom af class start isn swear use waiting seeing somebody nah bored called ima place poor
# Topic #9:
# need thanks make new damn home long game fun song weekend hot guy cold welcome awesome everybody definitely link party
# Topic #10:
# miss going ve bad best yes actually bro dead food believe eat care wow working took thinking feels album super
# Topic #11:
# shit today didn way little soon person forgot seriously half saying aw fucked fan scared sound summer gave problem luck
# Topic #12:
# hope look days week okay help haven hurt meet eyes gets family sweet brother weeks rest aww feelings bit absolutely
# Topic #13:
# got sad school ain tired try looks coming lot free money bruh late sister win 11 ugly second headache everyday
# Topic #14:
# love really sorry wanna fucking yeah feeling amazing mean check making crying friday saw boyfriend eating woke nap stupid months
# Topic #15:
# just don let say stop thing ya wanna watching idk anymore remember hear knew kill laugh yall happened different tried
# Topic #16:
# work ass hard trying gone things yo haha text wtf times tweets came early glad following tryna die says course
# Topic #17:
# lol thank baby girl thought doing pretty sure crazy dream worst hello bae close wake moment cut sucks congrats notice
# Topic #18:
# omg video watch facetimemenash twitter new nigga tweet kanye dm car excited true forget nash honestly taking subscribe missed ugh
# Topic #19:
# good happy ll sleep birthday night wait rt great morning ur hey nice gt play friend looking away went guess

# %%
data_lda=lda.transform(tf)

# %%
data_lda.shape
# Out:
# (50000, 20)
